# %% [markdown]
# Instructions
# --------------
# This is intended to provide you with a simple interface to play with transit light-curves. By simply providing the parameters, you can inspect the resulting transit light-curve and determine the quality of fit to a simple mock data set.
#
# First, take a look at the graph at the bottom of this page. It's fairly obvious that the model transit light-curve displayed does not fit the data very well. At the top-center of the graph is the chi-squared per degree of freedom statistic $\chi_{dof}^2$ assessing the quality of the fit. With the parameters entered below, it's initial value is 9.89. For a good fit, this statistic should be about 1. Your job is to modify the parameters of the transit light-curve until $\chi_{dof}^2 \leq 1.2$.
#
# Enter the parameters of your transit in the cell below:
# - depth : The depth of the transit. Must be between 0 and 1 (inclusive).
# - ingress_start : Time of the start of ingress in seconds. Must be positive.
# - ingress_end : Time of the end of ingress in seconds. Must be larger than ingress_start.
# - egress_start : Time of the start of egress in seconds. Must be larger than ingress_end.
# - egress_end : Time of the end of egress in seconds. Must be larger than egress_start.
#
# **Do not** modify the second cell - the one starting with ``%matplotlib inline``. When you are finished entering this information, run this notebook by clicking on Kernel in the menu above and selecting "Restart & Run All." Confirm that you would like to do so by then selecting "Restart and Run All Cells." The plot of your transit lightcurve will be shown at the bottom of the page, where you may then download a copy of it.

# %%
depth = 0.015  
ingress_start = 9000 
ingress_end = 11000 
egress_start = 25000 
egress_end = 28000

# %% [markdown]
# **Do not** modify the cell below.

# %%
# %matplotlib inline 
import src 
src.transit(depth, ingress_start, ingress_end, egress_start, egress_end).show()
